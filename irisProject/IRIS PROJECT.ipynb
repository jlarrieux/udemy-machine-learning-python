# %% [markdown]
# # Iris Project
# ## Data exploration and Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
df = pd.read_csv('iris.data', header=-1)

# %%
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
col_name = ['sepal length',   'sepal width',   'petal length',   'petal width',   'class' ]

# %%
df.columns= col_name

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Iris Data From Seaborn

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris.groupby('species').size())
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# # Visualization

# %%
sns.pairplot(iris, hue='species', size =4, aspect=1);

# %%
iris.hist(edgecolor= 'black', linewidth=5, figsize=(18,8));

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.violinplot(x='species', y='sepal_length', data=iris)
plt.subplot(2,2,2)
sns.violinplot(x='species', y='sepal_width', data=iris)
plt.subplot(2,2,3)
sns.violinplot(x='species', y='petal_length', data=iris)
plt.subplot(2,2,4)
sns.violinplot(x='species', y='petal_width', data=iris)

# %%
iris.boxplot(by='species', figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002BD285470B8>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(iris, figsize=(12,10));

# %% [markdown]
# # scikit-learn
# ## url = http://scikit-learn.org/stable/

# %%
# %%HTML
# <iframe width=100% height=800 src='http://scikit-learn.org/stable/'></iframe>
# Out:
# <iframe width=100% height=800 src='http://scikit-learn.org/stable/'></iframe>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Supervised Learning: Simple Linear Regression

# %%
x = 100*np.random.rand(100)

# %%
y= -5 * x + np.random.rand(100)

# %%
plt.scatter(x,y);

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression(fit_intercept=True)

# %%
model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
X= x.reshape(-1,1)
X.shape
# Out:
# (100, 1)

# %%
model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.coef_
# Out:
# array([-5.00034313])

# %%
model.intercept_
# Out:
# 0.485761311859477

# %%
x_fit = np.linspace(-1, 110)

# %%
X_fit = x_fit.reshape(-1,1)

# %%
y_fit = model.predict(X_fit)

# %%
plt.scatter(x,y)
plt.scatter(x_fit, y_fit)
